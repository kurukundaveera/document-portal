# %%
print("all ok")
# Out:
# all ok

# %%
import logging
import os
from datetime import datetime

# %% [markdown]
# # For capturin log will create one directory and all log files will be placed their

# %%
logs_dir=os.path.join(os.getcwd(),"logs")

# %%
os.makedirs(logs_dir,exist_ok=True)

# %% [markdown]
# # Now will Create the log file

# %%
LOG_FILE=f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"

# %%
LOG_FILE
# Out:
# '09_29_2025_13_29_15.log'

# %%
LOG_FILE
# Out:
# '09_29_2025_13_29_15.log'

# %%
LOG_FILE_PATH=os.path.join(logs_dir, LOG_FILE)

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
    format="[ %(asctime)s ] %(levelname)s %(name)s (line:%(lineno)d) - %(message)s",
    level=logging.INFO,
)

# %%
logger=logging.getLogger("DocumentPortal")

# %%
logger.info("This is an info message")

# %%
import structlog
log=structlog.get_logger()

# %%
log.info("user uploaded a file", user_id=123, filename="report.pdf")
# Out:
# 2025-09-29 13:29:15 [info     ] user uploaded a file           filename=report.pdf user_id=123

# %%
log.error("Failed to process PDF", error="File not found", user_id=123)
# Out:
# 2025-09-29 13:29:15 [error    ] Failed to process PDF          error='File not found' user_id=123
